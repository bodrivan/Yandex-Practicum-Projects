# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Вспомогательные-фукнции" data-toc-modified-id="Вспомогательные-фукнции-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Вспомогательные фукнции</a></span></li><li><span><a href="#Импорт-данных" data-toc-modified-id="Импорт-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Импорт данных</a></span></li><li><span><a href="#Основная-информация-о-данных" data-toc-modified-id="Основная-информация-о-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Основная информация о данных</a></span></li><li><span><a href="#Изменение-типов-данных-и-индексации" data-toc-modified-id="Изменение-типов-данных-и-индексации-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Изменение типов данных и индексации</a></span></li><li><span><a href="#Ресемплирование-и-декомпозиция" data-toc-modified-id="Ресемплирование-и-декомпозиция-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Ресемплирование и декомпозиция</a></span></li></ul></li><li><span><a href="#Анализ" data-toc-modified-id="Анализ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-анализу" data-toc-modified-id="Вывод-по-анализу-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Вывод по анализу</a></span></li></ul></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обучение</a></span><ul class="toc-item"><li><span><a href="#Создание-метрики-для-автоматического-подбора-гиперпараметров" data-toc-modified-id="Создание-метрики-для-автоматического-подбора-гиперпараметров-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Создание метрики для автоматического подбора гиперпараметров</a></span></li><li><span><a href="#Добавление-признаков" data-toc-modified-id="Добавление-признаков-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавление признаков</a></span></li><li><span><a href="#Разделение-на-выборки" data-toc-modified-id="Разделение-на-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Разделение на выборки</a></span></li><li><span><a href="#Разделение-на-признаки-и-целевой-признак" data-toc-modified-id="Разделение-на-признаки-и-целевой-признак-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Разделение на признаки и целевой признак</a></span></li><li><span><a href="#Обучение-и-проверка-моделей" data-toc-modified-id="Обучение-и-проверка-моделей-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Обучение и проверка моделей</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Результаты-выбора-модели" data-toc-modified-id="Результаты-выбора-модели-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Результаты выбора модели</a></span></li></ul></li><li><span><a href="#Тестирование" data-toc-modified-id="Тестирование-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование</a></span><ul class="toc-item"><li><span><a href="#Предсказание-значений-временного-ряда-на-наилучшей-модели" data-toc-modified-id="Предсказание-значений-временного-ряда-на-наилучшей-модели-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Предсказание значений временного ряда на наилучшей модели</a></span></li><li><span><a href="#Сравнительные-графики-предсказаний" data-toc-modified-id="Сравнительные-графики-предсказаний-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Сравнительные графики предсказаний</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# #  Прогнозирование заказов такси

# %% [markdown]
# Компания «Чётенькое такси» собрала исторические данные о заказах такси в аэропортах. Чтобы привлекать больше водителей в период пиковой нагрузки, нужно спрогнозировать количество заказов такси на следующий час. Постройте модель для такого предсказания.
#
# Значение метрики *RMSE* на тестовой выборке должно быть не больше 48.
#
# Данные лежат в файле `taxi.csv`. Количество заказов находится в столбце `num_orders` (от англ. *number of orders*, «число заказов»).

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import TimeSeriesSplit

# %% [markdown]
# ### Вспомогательные фукнции

# %%
def root_mean_squared_error(true, pred):
    import math
    return math.sqrt(mean_squared_error(true, pred))

# %%
def make_features(data, max_lag, rolling_mean_size):
    data['hour'] = data.index.hour
    data['dayofweek'] = data.index.dayofweek
    
    for lag in range(1, max_lag + 1):
        data['lag_{}'.format(lag)] = data['num_orders'].shift(lag)

    data['rolling_mean'] = data['num_orders'].shift().rolling(rolling_mean_size).mean()

# %% [markdown]
# ### Импорт данных

# %%
path_1 = '/Users/ivanbodrenkov/Yandex.Disk.localized/Яндекс Практикум/12. Временные ряды/Проект/taxi.csv'
path_2 = 'https://code.s3.yandex.net/datasets/taxi.csv'
path_3 = 'C:/Users/bodrenkov_ia/Desktop/Project/taxi.csv'
path_4 = '/datasets/taxi.csv'

if os.path.exists(path_1):
    data = pd.read_csv(path_1, sep = ',')
elif os.path.exists(path_2):
    data = pd.read_csv(path_2, sep = ',')
elif os.path.exists(path_3):
    data = pd.read_csv(path_3, sep = ',')
elif os.path.exists(path_4):
    data = pd.read_csv(path_4, sep = ',')
else:
    print('Что-то пошло не так!')

# %% [markdown]
# ### Основная информация о данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26496 entries, 0 to 26495
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    26496 non-null  object
#  1   num_orders  26496 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 414.1+ KB

# %%
data.head()
# Out:
#               datetime  num_orders
# 0  2018-03-01 00:00:00           9
# 1  2018-03-01 00:10:00          14
# 2  2018-03-01 00:20:00          28
# 3  2018-03-01 00:30:00          20
# 4  2018-03-01 00:40:00          32

# %% [markdown]
# ### Изменение типов данных и индексации

# %%
data['datetime'] = pd.to_datetime(data['datetime'])
data = data.set_index('datetime')

# %%
print(data.index.is_monotonic)
# Out:
# True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 26496 entries, 2018-03-01 00:00:00 to 2018-08-31 23:50:00
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   num_orders  26496 non-null  int64
# dtypes: int64(1)
# memory usage: 414.0 KB

# %%
data.head()
# Out:
#                      num_orders
# datetime
# 2018-03-01 00:00:00           9
# 2018-03-01 00:10:00          14
# 2018-03-01 00:20:00          28
# 2018-03-01 00:30:00          20
# 2018-03-01 00:40:00          32

# %% [markdown]
# ### Ресемплирование и декомпозиция

# %%
data = data.resample('1H').sum()
data_decomposed = seasonal_decompose(data)

# %% [markdown]
# ## Анализ

# %%
fig = plt.figure(figsize = (15, 35))

ax1 = fig.add_subplot(911)
ax2 = fig.add_subplot(912)
ax3 = fig.add_subplot(913)
ax4 = fig.add_subplot(914)
ax5 = fig.add_subplot(915)
ax6 = fig.add_subplot(916)
ax7 = fig.add_subplot(917)


ax1.plot(data)
ax1.set_title('Временной ряд')

ax2.plot(data.rolling(100).mean())
ax2.set_title('Скользящее среднее (окно - 100)')

ax3.plot(data_decomposed.seasonal)
ax3.set_title('Сезонность')

ax4.plot(data_decomposed.seasonal['2018-08-01 00:00:00' : '2018-08-02 00:00:00'])
ax4.set_title('Сезонность (увел.)')

ax5.plot(data_decomposed.trend)
ax5.set_title('Тренд')

ax6.plot(data_decomposed.resid)
ax6.set_title('Остаток')

ax7.plot(data['num_orders'].rolling(100).std())
ax7.set_title('Скользящее стандартное отклонение')
# Out:
# Text(0.5, 1.0, 'Скользящее стандартное отклонение')

# %% [markdown]
# ### Вывод по анализу

# %% [markdown]
# В процессе подготовки и анализа были импортированы данные, изменен тип данных в строке с датами, даты проверены на монотонность и превращены в индексы датасета. Произведено ресемплирование данных, а также их декомпозиция для получения графиков сезонности и тренда. Построены графики временного ряда, скользящего среднего, тренда, сезонности, сезонности по дню, остатка и скользящего стандартного отклонения. Обнаружен общий восходящий тренд, а также "сезонность по дню". Заказы минимальны ранним утром (в 6 утра), во время утреннего и вечернего часов пик есть локальные максимумы, после которых идет спад. После вечернего спада идет рост до полуночи - времени с наибольшим количеством заказов.

# %% [markdown]
# ## Обучение

# %% [markdown]
# ### Создание метрики для автоматического подбора гиперпараметров

# %%
RMSE_score = make_scorer(root_mean_squared_error, greater_is_better = False)

# %% [markdown]
# ### Добавление признаков

# %%
make_features(data, 5, 10)
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4406 entries, 2018-03-01 10:00:00 to 2018-08-31 23:00:00
# Freq: H
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   num_orders    4406 non-null   int64
#  1   hour          4406 non-null   int64
#  2   dayofweek     4406 non-null   int64
#  3   lag_1         4406 non-null   float64
#  4   lag_2         4406 non-null   float64
#  5   lag_3         4406 non-null   float64
#  6   lag_4         4406 non-null   float64
#  7   lag_5         4406 non-null   float64
#  8   rolling_mean  4406 non-null   float64
# dtypes: float64(6), int64(3)
# memory usage: 344.2 KB

# %%
data.head()
# Out:
#                      num_orders  hour  dayofweek  lag_1  lag_2  lag_3  lag_4  \
# datetime
# 2018-03-01 10:00:00          64    10          3   69.0   34.0   15.0   12.0
# 2018-03-01 11:00:00          96    11          3   64.0   69.0   34.0   15.0
# 2018-03-01 12:00:00          30    12          3   96.0   64.0   69.0   34.0
# 2018-03-01 13:00:00          32    13          3   30.0   96.0   64.0   69.0
# 2018-03-01 14:00:00          48    14          3   32.0   30.0   96.0   64.0
#
#                      lag_5  rolling_mean
# datetime
# 2018-03-01 10:00:00    6.0          52.5
# 2018-03-01 11:00:00   12.0          46.5
# 2018-03-01 12:00:00   15.0          47.6
# 2018-03-01 13:00:00   34.0          43.5
# 2018-03-01 14:00:00   69.0          40.1

# %% [markdown]
# ### Разделение на выборки

# %%
train, test = train_test_split(data, shuffle = False, test_size = 0.1)

print('Крайние индексы обучающей выборки', train.index.min(), '\t', train.index.max())
print('Крайние индексы тестовой выборки', test.index.min(), '\t', test.index.max())
# Out:
# Крайние индексы обучающей выборки 2018-03-01 10:00:00 	 2018-08-13 14:00:00
# Крайние индексы тестовой выборки 2018-08-13 15:00:00 	 2018-08-31 23:00:00

# %% [markdown]
# ### Разделение на признаки и целевой признак

# %%
features_train = train.drop('num_orders', axis = 1)
target_train = train['num_orders']
features_test = test.drop('num_orders', axis = 1)
target_test = test['num_orders']

# %% [markdown]
# ### Обучение и проверка моделей

# %% [markdown]
# #### Линейная регрессия

# %%
model_1 = LinearRegression()
model_1_score = cross_val_score(model_1,features_train, target_train, 
                                cv = TimeSeriesSplit(n_splits = 5), 
                                n_jobs = -1, 
                                scoring = RMSE_score).mean()

# %%
# %%time
model_1.fit(features_train, target_train)
# Out:
# CPU times: user 10.7 ms, sys: 9.15 ms, total: 19.8 ms
# Wall time: 12.6 ms
# LinearRegression()

# %%
# %%time
predictions_1 = model_1.predict(features_train)
# Out:
# CPU times: user 4.52 ms, sys: 2.34 ms, total: 6.86 ms
# Wall time: 2.3 ms

# %%
print('RMSE =', abs(model_1_score))
# Out:
# RMSE = 32.64631985448143

# %%
# обучение линейной регрессией
model = LinearRegression()

print(f'''Значение метрики RMSE на обучающей выборке для LinearRegression''', cross_val_score(model,features_train, target_train, 
                         cv = TimeSeriesSplit(n_splits = 5), 
                         n_jobs = -1, 
                         scoring = RMSE_score).mean())
# Out:
# Значение метрики RMSE на обучающей выборке для LinearRegression -32.64631985448143

# %% [markdown]
# ####  Решающее дерево

# %%
# %%time
decision_tree_grid_space = {'max_depth' : [1, 2, 4, 8],
                            'min_samples_leaf' : [1, 2, 3]
                           }

model = DecisionTreeRegressor()

time_series_cross_val = TimeSeriesSplit(n_splits = 5)
grid = GridSearchCV(estimator = model, 
                    param_grid = decision_tree_grid_space, 
                    scoring = RMSE_score, 
                    n_jobs = -1, 
                    cv = time_series_cross_val, 
                    verbose = 1)
model_grid = grid.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# CPU times: user 86.3 ms, sys: 15.3 ms, total: 102 ms
# Wall time: 658 ms

# %%
print('Лучшие гиперпараметры:', model_grid.best_params_)
# Out:
# Лучшие гиперпараметры: {'max_depth': 8, 'min_samples_leaf': 3}

# %%
model_2 = DecisionTreeRegressor(
    max_depth = int(model_grid.best_params_['max_depth']), 
    min_samples_leaf = int(model_grid.best_params_['min_samples_leaf']))

# %%
# %%time
model_2.fit(features_train, target_train)
# Out:
# CPU times: user 13 ms, sys: 1.29 ms, total: 14.3 ms
# Wall time: 12.6 ms
# DecisionTreeRegressor(max_depth=8, min_samples_leaf=3)

# %%
print('RMSE =', abs(model_grid.best_score_))
# Out:
# RMSE = 29.424584074143088

# %% [markdown]
# #### Случайный лес

# %%
# %%time
random_forest_grid_space = {'n_estimators' : [100, 200, 300], 
                            'max_depth' : [1, 2, 4, 8, 10, 12],
                            'min_samples_leaf' : [1, 2, 3]
                           }

model = RandomForestRegressor()

time_series_cross_val = TimeSeriesSplit(n_splits = 5)
grid = GridSearchCV(estimator = model, 
                    param_grid = random_forest_grid_space, 
                    scoring = RMSE_score, 
                    n_jobs = -1, 
                    cv = time_series_cross_val, 
                    verbose = 1)
model_grid = grid.fit(features_train, target_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# CPU times: user 2.4 s, sys: 119 ms, total: 2.52 s
# Wall time: 35.7 s

# %%
print('Лучшие гиперпараметры:', model_grid.best_params_)
# Out:
# Лучшие гиперпараметры: {'max_depth': 12, 'min_samples_leaf': 2, 'n_estimators': 200}

# %%
model_3 = RandomForestRegressor(
    n_estimators = int(model_grid.best_params_['n_estimators']), 
    max_depth = int(model_grid.best_params_['max_depth']), 
    min_samples_leaf = int(model_grid.best_params_['min_samples_leaf']))

# %%
# %%time
model_3.fit(features_train, target_train)
# Out:
# CPU times: user 1.81 s, sys: 20.5 ms, total: 1.83 s
# Wall time: 1.84 s
# RandomForestRegressor(max_depth=12, min_samples_leaf=2, n_estimators=200)

# %%
print('RMSE =', abs(model_grid.best_score_))
# Out:
# RMSE = 26.064408509999407

# %% [markdown]
# ### Результаты выбора модели

# %% [markdown]
# |Модель|RMSE|
# |:-|:-:|
# |Линейная регрессия|32.646|
# |Решающее дерево|29.397|
# |Случайный лес|**26.797**|

# %% [markdown]
# ## Тестирование

# %% [markdown]
# ### Предсказание значений временного ряда на наилучшей модели

# %%
# %%time
predictions_test = model_3.predict(features_test)
# Out:
# CPU times: user 15.5 ms, sys: 1.77 ms, total: 17.2 ms
# Wall time: 16.8 ms

# %%
print('RMSE =', root_mean_squared_error(target_test, predictions_test))
# Out:
# RMSE = 47.098407429322954

# %% [markdown]
# ### Сравнительные графики предсказаний

# %%
predictions_test = pd.Series(data = predictions_test, index = target_test.index)

fig = plt.figure(figsize = (15, 15))

ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)


ax1.plot(target_test, label = 'Истинные значения ряда')
ax1.plot(predictions_test, label = 'Предсказанные значения ряда')
ax1.set_title('Сравнение предсказанной части временного ряда (истинное и предсказанное моделью)')
ax1.legend(loc = 2)
ax1.tick_params(axis = 'x', labelrotation = 45)


ax2.plot(target_test.rolling(10).mean(),label = 'Истинные значения ряда')
ax2.plot(predictions_test.rolling(10).mean(), label = 'Предсказанные значения ряда')
ax2.set_title('Сравнение предсказанной части временного ряда (истинное и предсказанное моделью, скользящее среднее)')
ax2.legend(loc = 2)
ax2.tick_params(axis = 'x', labelrotation = 45)

print(type(target_test))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Вывод

# %% [markdown]
# В ходе работы были произведены обработка и анализ данных, обучение моделей и тестирование наилучшей модели. Во время  обработки обнаружена "дневная сезонность". В течение дня есть локальные максимумы количества заказов во время утреннего и вечернего часа пик и в полночь. Полуночный пик самый высокий, но за ним следует самый глубокий спад количества заказов, приходящийся на раннее утро (6 утра). Обнаружен общий тренд к увеличению количества заказов.
#
# Обучены три вида моделей: линейная регрессия, решающее дерево и случайный лес. Для всех моделей проведена кросс-валидация. Ниже представлены метрики наилучших моделей и время поиска параметров, обучения, предсказания.
#
# |  |Линейная регрессия|Решающее дерево|Случайный лес|
# |:-|:-:|:-:|:-:|
# |RMSE|32.646|29.425|**26.065**|
# |Время обучения модели|12.6 милисек|12.6 милисек|1.84 сек|
# |Время поиска гиперпараметров|-|658 милисек|35.7 сек|
#
# Наилучшая модель была протестирована. Результаты тестирования представлены ниже.
#
# |  |Случайный лес|
# |:-|:-:|
# |RMSE|47.099|
# |Время предсказания модели|16.8 милисек|
#
# Наилучшая модель - случайный лес с гиперпараметрами: max_depth = 12, min_samples_leaf = 2, n_estimators = 200. RMSE = 47.099. Построены сравнительные графики для предсказаний.
